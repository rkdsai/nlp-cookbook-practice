# %%
from transformers import pipeline
import torch_directml
device = torch_directml.device()
print("Using device:", device)
# Out:
# Using device: privateuseone:0

# %% [markdown]
# i am using intel arc GPU
#
# import torch
# import torch_directml
#
# device = torch_directml.device()
# print("Using device:", device)

# %%
text = "The cat had no business entering the neighbors garage, but"

# %%
generator = pipeline('text-generation', model='gpt2', device=-1)

# %%
generated_sentences = generator(text, do_sample=True, max_length=30, num_return_sequences=5, num_beams=5, pad_token_id=50256)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
[print(generated_sentence['generated_text']) for generated_sentence in generated_sentences]
# Out:
# The cat had no business entering the neighbors garage, but when the police arrived, they found the cat lying on the floor.
#
# The cat was
# The cat had no business entering the neighbors garage, but when the police arrived, they found the cat lying on the floor.
#
# The cat had
# The cat had no business entering the neighbors garage, but when the police arrived, they found the cat lying on the floor.
#
# The cat's
# The cat had no business entering the neighbors garage, but when the police arrived, they found the cat lying on the floor.
#
# The cat,
# The cat had no business entering the neighbors garage, but when the police arrived, they found the cat lying on the floor.
#
# The police determined
# [None, None, None, None, None]

# %%
generated_sentences = generator(text, do_sample=True, max_length=30, num_return_sequences=5, num_beams=5, no_repeat_ngram_size=2,  pad_token_id=50256)
[print(generated_sentence['generated_text']) for generated_sentence in generated_sentences]
# Out:
# The cat had no business entering the neighbors garage, but when he saw it, he ran out of the house.
#
# "I didn't know
# The cat had no business entering the neighbors garage, but when he saw it, he ran out of the house.
#
# "I didn't want
# The cat had no business entering the neighbors garage, but when he saw it, he ran out of the house.
#
# "I didn't even
# The cat had no business entering the neighbors garage, but when he saw it, he ran out of the house.
#
# "I didn't see
# The cat had no business entering the neighbors garage, but when he saw it, he ran out of the house.
#
# "I think it was
# [None, None, None, None, None]

# %%
generated_sentences = generator(text, do_sample=True, max_length=30, num_return_sequences=5, num_beams=5, no_repeat_ngram_size=2,
                               top_k=50, pad_token_id=50256)
[print(generated_sentence['generated_text']) for generated_sentence in generated_sentences]
# Out:
# The cat had no business entering the neighbors garage, but when he tried to go inside, he was arrested.
#
# He was then taken into custody
# The cat had no business entering the neighbors garage, but when he tried to go inside, he was arrested.
#
# "He said he wanted to
# The cat had no business entering the neighbors garage, but when he tried to go inside, he was arrested.
#
# "He said he had to
# The cat had no business entering the neighbors garage, but when he tried to go inside, he was arrested.
#
# "I'm not a criminal
# The cat had no business entering the neighbors garage, but when he tried to go inside, he was arrested.
#
# "He said he had just
# [None, None, None, None, None]

# %%
generated_sentences = generator(text, do_sample=True, max_length=500, num_return_sequences=1, num_beams=5, no_repeat_ngram_size=2,
                               top_k=50, top_p=0.85, pad_token_id=50256)
[print(generated_sentence['generated_text']) for generated_sentence in generated_sentences]
# Out:
# The cat had no business entering the neighbors garage, but when he went inside, he found the door locked.
#
# "He said, 'I don't know what's going on, I'm not going to let you in,' and I told him I didn't have anything to do with it," he said.
# [None]
