# %%
# Install Deep Pavlov and the dependent modules
# !python -m deeppavlov install en_odqa_infer_wiki
# Out:
# c:\Users\ravik\anaconda3\envs\nlp_cookbook\python.exe: No module named deeppavlov

# %%
from deeppavlov import build_model

odqa = build_model('en_odqa_infer_wiki', download=True)
result = odqa(['What is the name of the Doctor in Star Trek?'])
print(result)
# Out:
# 2026-01-27 18:25:03.379 INFO in 'deeppavlov.core.data.utils'['utils'] at line 97: Downloading from http://files.deeppavlov.ai/deeppavlov_data/odqa/enwiki_tfidf_matrix_par_lite.tar.gz to C:\Users\ravik\.deeppavlov\models\enwiki_tfidf_matrix_par_lite.tar.gz
# 100%|██████████| 551M/551M [01:03<00:00, 8.68MB/s]
# 2026-01-27 18:26:08.230 INFO in 'deeppavlov.core.data.utils'['utils'] at line 284: Extracting C:\Users\ravik\.deeppavlov\models\enwiki_tfidf_matrix_par_lite.tar.gz archive into C:\Users\ravik\.deeppavlov\models\odqa
# 2026-01-27 18:26:14.321 INFO in 'deeppavlov.core.data.utils'['utils'] at line 97: Downloading from http://files.deeppavlov.ai/deeppavlov_data/odqa/nq_psgcls_bert.tar.gz to C:\Users\ravik\.deeppavlov\models\nq_psgcls_bert.tar.gz
# 100%|██████████| 405M/405M [00:46<00:00, 8.69MB/s]
# ...

# %%
result = odqa(["Where did guinea pigs originate?", "When did the Lynmouth floods happen?", "When is the Bastille Day?"])
print(result)
