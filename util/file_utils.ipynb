# %%
import os
print(os.getcwd())
# Out:
# c:\Users\ravik\Documents\nlp_cookbook\Python-Natural-Language-Processing-Cookbook-Second-Edition\util

# %%
def read_text_file(filename):
    file = open(filename, "r", encoding="utf-8") 
    return file.read()
