# %%
import re
import pandas as pd

# %%
data_file = "../data/DataScientist.csv"
df = pd.read_csv(data_file, encoding='utf-8')
print(df)
# Out:
#       Unnamed: 0  index                                          Job Title  \
# 0              0      0                              Senior Data Scientist
# 1              1      1                  Data Scientist, Product Analytics
# 2              2      2                               Data Science Manager
# 3              3      3                                       Data Analyst
# 4              4      4                             Director, Data Science
# ...          ...    ...                                                ...
# 3904        3904   4375                                  AWS Data Engineer
# 3905        3905   4376                              Data Analyst â Junior
# 3906        3906   4377                   Security Analytics Data Engineer
# 3907        3907   4378                   Security Analytics Data Engineer
# 3908        3908   4379  Patient Safety Physician or Safety Scientist -...
#
#                    Salary Estimate  \
# 0     $111K-$181K (Glassdoor est.)
# 1     $111K-$181K (Glassdoor est.)
# 2     $111K-$181K (Glassdoor est.)
# 3     $111K-$181K (Glassdoor est.)
# 4     $111K-$181K (Glassdoor est.)
# ...                            ...
# 3904   $55K-$112K (Glassdoor est.)
# 3905   $55K-$112K (Glassdoor est.)
# 3906   $55K-$112K (Glassdoor est.)
# 3907   $55K-$112K (Glassdoor est.)
# 3908   $55K-$112K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     ABOUT HOPPER\r\n\r\nAt Hopper, we’re on a miss...     3.5
# 1     At Noom, we use scientifically proven methods ...     4.5
# 2     Decode_M\r\n\r\nhttps://www.decode-m.com/\r\n\...    -1.0
# 3     Sapphire Digital seeks a dynamic and driven mi...     3.4
# 4     Director, Data Science - (200537)\r\nDescripti...     3.4
# ...                                                 ...     ...
# 3904  About Us\r\n\r\nTachyon Technologies is a Digi...     4.4
# 3905  Job description\r\nInterpret data, analyze res...     5.0
# 3906  Job DescriptionThe Security Analytics Data Eng...     3.8
# 3907  The Security Analytics Data Engineer will inte...     4.0
# 3908  Help us transform patients' lives.\r\nAt UCB, ...     3.7
#
#                                  Company Name       Location  \
# 0                               Hopper\r\n3.5   New York, NY
# 1                              Noom US\r\n4.5   New York, NY
# 2                                    Decode_M   New York, NY
# 3                     Sapphire Digital\r\n3.4  Lyndhurst, NJ
# 4           United Entertainment Group\r\n3.4   New York, NY
# ...                                       ...            ...
# 3904              Tachyon Technologies\r\n4.4     Dublin, OH
# 3905  Staffigo Technical Services, LLC\r\n5.0   Columbus, OH
# 3906                    PDS Tech, Inc.\r\n3.8     Dublin, OH
# 3907        Data Resource Technologies\r\n4.0     Dublin, OH
# 3908                               UCB\r\n3.7     Slough, OH
#
#           Headquarters                     Size  Founded  Type of ownership  \
# 0     Montreal, Canada    501 to 1000 employees     2007  Company - Private
# 1         New York, NY   1001 to 5000 employees     2008  Company - Private
# 2         New York, NY        1 to 50 employees       -1            Unknown
# 3        Lyndhurst, NJ     201 to 500 employees     2019  Company - Private
# 4         New York, NY      51 to 200 employees     2007  Company - Private
# ...                ...                      ...      ...                ...
# 3904        Irving, TX     201 to 500 employees     2011  Company - Private
# 3905     Woodridge, IL      51 to 200 employees     2008  Company - Private
# 3906        Irving, TX  5001 to 10000 employees     1977  Company - Private
# 3907         Omaha, NE        1 to 50 employees       -1  Company - Private
# 3908  Brussel, Belgium  5001 to 10000 employees       -1   Company - Public
#
#                        Industry                     Sector  \
# 0               Travel Agencies           Travel & Tourism
# 1     Health, Beauty, & Fitness          Consumer Services
# 2                            -1                         -1
# 3                      Internet     Information Technology
# 4       Advertising & Marketing          Business Services
# ...                         ...                        ...
# 3904                IT Services     Information Technology
# 3905                IT Services     Information Technology
# 3906     Staffing & Outsourcing          Business Services
# 3907                 Accounting         Accounting & Legal
# 3908  Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
#
#                          Revenue               Competitors Easy Apply
# 0       Unknown / Non-Applicable                        -1         -1
# 1       Unknown / Non-Applicable                        -1         -1
# 2       Unknown / Non-Applicable                        -1       True
# 3       Unknown / Non-Applicable      Zocdoc, Healthgrades         -1
# 4       Unknown / Non-Applicable  BBDO, Grey Group, Droga5         -1
# ...                          ...                       ...        ...
# 3904    $10 to $25 million (USD)                        -1         -1
# 3905   $50 to $100 million (USD)                        -1         -1
# 3906  $100 to $500 million (USD)                        -1         -1
# 3907  Less than $1 million (USD)                        -1         -1
# 3908      $2 to $5 billion (USD)                    AbbVie         -1
#
# [3909 rows x 17 columns]

# %%
def get_list_of_items(df, column_name):
    values = df[column_name].values
    values = [item for sublist in values for item in sublist]
    list_of_items = list(set(values))
    return list_of_items

# %%
def get_emails(df):
    email_regex = '[^\s:|()\']+@[a-zA-Z0-9\.]+\.[a-zA-Z]+'
    df['emails'] = df['Job Description'].apply(lambda x: re.findall(email_regex, x))
    emails = get_list_of_items(df, 'emails')
    return emails

# %%
emails = get_emails(df)
print(emails)
# Out:
# ['hr@texastoolbelt.com.com', 'rama.diverse@gmail.com', 'irvine@camdenkelly.com', 'algo__autobench_research_scientist_a84151f42us@ivy.greenhouse.io', 'Âanvesh@conchtech.com', 'Brooke.Schoen@kellyservices.com', 'statjobs@austin.utexas.edu', 'careers@edo.com', 'jim@ingenium.agency', 'ajones@simplybiotech.com', 'HR@dtexsystems.com', 'CareersUS@QVC.com', 'naveen@dsiginc.com', 'talent.acquisition@servicenow.com', 'Kerry.orton@nationwidechildrens.org', 'accommodations@relx.com.Elsevier', 'Lilly_Recruiting_Compliance@lists.lilly.com', 'kevin@ingenium.agency', 'dallas@camdenkelly.com', 'brenna.boies@cybercoders.com', 'mani@net2source.com', 'shobana@infowaygroup.com', 'compliance@integralads.com.To', 'Application_Accommodation@colpal.com', 'dani@pavetalent.com', 'ekingery@apexsystems.com', 'hala.hillo@motektech.com', 'employeeservices@apexsystemsinc.com', 'dkuphal@myvoca.com', 'Âbhavna@tekleaders.com', 'MyRecruiter@alere.com', 'US_Employment_Compliance@cgi.com', 'careers@mpulsemobile.com', 'careers@Healthfirst.org', 'accommodations@relx.com', 'bridget@alphaconsulting.com', 'privacy@honest.com', 'dneto@apexsystems.com', 'Rohan.g@avacend.com', 'vishal@arksolutionsinc.com', 'Talent.manager@techquarry.com', 'sdonovan@judge.com', 'resumes@nextgentechinc.com', 'shane@arksolutionsinc.com', 'mturner@simplybiotech.com', 'disability-accommodations@treehousefoods.com', 'TalentAcquisition@email.chop.edu', 'bflores1@lacourt.org', 'Accommodation.Reques@am.jll.com', 'Prajwal.Rajappa@nationwidechildrens.org', 'agiangiulio@fredbeans.com', 'info@njf.com', 'tharrell@chiptonross.com', 'Melissa@kingmelissa.com', 'recruitment@numericjobs.com', 'accommodations@koniag.com', 'mike.pachella@sig.com', 'hr@exponent.com', 'gjimenez@uic.edu', 'Marcus.Quigley@cybercoders.com', 'lhatteme@usc.edu', 'Phila.OHR@phila.gov', 'hesquivel@deaconrecruiting.com', 'neeraj.h@avacend.com', 'faqpchr@phila.gov', 'atÂshravya@techprojects.us', 'hari.haran@wisemen.com', 'favalos@deaconrecruiting.com', 'sachin@apninc.com', 'pranali@fisecglobal.net', 'divyansh@net2source.com', 'bhavna@tekleaders.com', 'cvs_support@modernhire.com', 'tansib@infotreeglobal.com', 'talentacquisition@dexcom.com', 'mreilly@itechsolutions.com', 'usaccommodations@globalfoundries.com', 'ndarian@smithhanley.com', 'TONM369@kellyservices.com', 'vinay@logicplanet.com', 'hr@btsresearch.com', 'liza.k@wisemen.com', 'careers@springhealth.com', 'Careers.NorthAmerica@sap.com', 'kushal@nextgentechnologiesinc.com', 'accommodations@illumina.com', 'dgingerich@carisls.com', 'JEND557@kellyscientific.com', 'cgarza@mleehealthcare.com', 'karthik@infovision.com', 'info@springml.com', 'Âvikram@pddninc.net', 'careers@tredence.com', 'workday_recruiting@iqvia.com', 'sukh@arksolutionsinc.com', 'Mallikharjun@conchtech.com', 'jfowler@deaconrecruiting.com', 'rajeshk@avtechsol.com', 'RecruitingAccommodation@guidehouse.com', 'LMurray@TechUSA.net', 'paypalglobaltalentacquisition@paypal.com', 'andrew.cooper@modis.com', 'tom@emeraldresourcegroup.com', 'recruitingagencies@integralads.com', 'jsmith@quartethealth.com', 'backgroundcheck-inquiries@deshaw.com', 'Shibu.S@avacend.com', 'staffingaadar@msd.com', 'sai@kanisol.com', 'recruiting@kariusdx.com', 'bchitneedi@esharpedge.com', 'lyssa.heine@arlut.utexas.edu', 'Aleo431@KellyScientific.com', 'suda@sutoer.com', 'Careers.APJ@sap.com', 'khartley@apexsystems.com', 'dherbine@pipercompanies.com', 'Alok.Kumar@artech.com', 'Vikasy@apninc.com', 'TalentAcquisition@grubhub.com', 'bwaldron@apexsystems.com', 'rohit.mcdonald@prolim.com', 'shai879@kellyservices.com', 'accommodations@dollarshaveclub.com', 'Amit@apninc.com', 'Ârakesh@athreyainc.com', 'AMunoz4@dhs.lacounty.gov', 'ldmayberry@apexsystems.com', 'Josh.carlos@itbtalent.com', 'hr@cloudflare.com', 'shaylyn.jaworowski@mondo.com', 'sjohnson@arcgonline.com', 'privacy@grubhub.com', 'shravya@techprojects.us', 'spam.leidos@leidos.com', 'ieo.mailbox@aero.org', 'naveen.remkumar@two95intl.com', 'tim@blackfynn.com', 'ignite@atos.netHere', 'krobinson@carisls.com', 'rec ...

# %%
def get_urls(df):
    url_regex = '(http[s]?://(www\.)?[A-Za-z0-9–_\.\-]+\.[A-Za-z]+/?[A-Za-z0-9$\–_\-\/\.]*)[\.)\"]*'
    df['urls'] = df['Job Description'].apply(lambda x: [x[item.span()[0]:item.span()[1]] for item in re.finditer(url_regex, x)])
    urls = get_list_of_items(df, 'urls')
    return urls

# %%
urls = get_urls(df)
print(urls)
# Out:
# ['https://www.decode-m.com/', 'https://www.instagram.com/fastswitchgl/', 'https://www.linkedin.com/in/emma-riley-72028917a/', 'https://www.nextstepsystems.com/jobseekers_submit_raul.html.', 'https://air.jd.com/', 'https://santannaenergyservices.com/', 'https://join.collectivehealth.com/box', 'https://benefits.northropgrumman.com/us/en2/BenefitsOverview/Pages/default.aspx', 'http://www.nasdaq.com', 'http://www.twdb.texas.gov/jobs/index.asp', 'http://adminrecords.ucsd.edu/PPM/docs/230-311.html', 'https://www.facebook.com/deeplensai/', 'https://tinyurl.com/ycqdhb98', 'http://iheartmediacareers.com/Pages/EEO.aspx', 'http://www.fujitsu.com/global/about/corporate/info/', 'https://portal.slac.stanford.edu/sites/lcls_public', 'http://cherokee-os.com/Pages/Home.aspx', 'https://jobs.gartner.com/applicant-privacy-policy', 'http://indeedhi.re/IndeedBenefits', 'https://apol-recruit.ucsd.edu/apply/JPF02126', 'http://www-hr.ucsd.edu/saa/nondiscr.htmlUC', 'http://www.cbica.upenn.edu/', 'https://h-gac.com/careers', 'http://cherokee-cnts.com/Pages/home.aspx', 'https://teladochealth.com/en/about/', 'http://adminguide.stanford.edu.', 'https://www.facebook.com/irisplans', 'http://www.eleverpro.com/executive-recruiter-jobs/', 'https://www.youtube.com/user/MindteckVideos', 'http://med.ucsd.edu', 'https://www.amazon.jobs/en/disability/us', 'https://www.nvidia.com/en-us/geforce/products/geforce-now/', 'https://www.builtinla.com/company/servicetitan-inc', 'http://instagram.com/lifeatservicetitan', 'https://www.linkedin.com/company/mindteck', 'https://www.mainlinehealth.org/careers', 'http://cherokee-cna.com/Pages/Home.aspx', 'https://www.opm.gov/policy-data-oversight/classification-qualifications/general-schedule-qualification-standards/0600/medical-technologist-series-0644/In', 'https://www.ebayinc.com/our-company/diversity-inclusion/.', 'http://www.tapestry.com/', 'https://www.gpo.gov/fdsys/pkg/CFR-2011-title20-vol3/pdf/CFR-2011-title20-vol3-sec656-3.pdf', 'http://www.mylife.com.', 'https://jobs.btginc.com.', 'http://www2.deloitte.com/us/en/pages/careers/topics/recruiting-tips.htmlCategory', 'https://www.nvidia.com/en-us/contact/', 'https://www.cslbehring.com/careers/eeo-statement', 'https://www.insight.com/en_US/about/newsroom/press-releases/2019/07012019-insight-recognized-at-no14-on-crns-2019-solution-provider-500-list.html', 'https://muse.cm/2t8eGlN', 'http://www.leoniegroup.com/careers', 'http://www.tomsofmaine.com.', 'https://www.ibm.com/analytics/', 'http://www.hr.sao.state.tx.us/Compensation/JobDescriptions.aspx.HHS', 'https://youtu.be/CC-seRMEo8s', 'https://cvshealth.com/covid-19', 'https://e-verify.uscis.gov/esp/media/resourcesContents/EverifyPosterSpanish.pdf', 'http://www.fujitsu.com/global/digitalannealer/', 'https://apol-recruit.ucsd.edu/apply/JPF02462', 'https://studentaid.ed.gov/sa/repay-loans/forgiveness-cancellation/public-service', 'http://www.compqsoft.com/current-openings.html', 'https://lnkd.in/e9ZpD5J', 'https://www.consumer.ftc.gov/JobScams', 'https://dnb.wd1.myworkdayjobs.com/Careers', 'https://youtu.be/QzKe9iZszD0', 'https://lnkd.in/ePyq7pM', 'https://lnkd.in/eqttaa4', 'http://cherokeenationbusinesses.com/federalSolutions', 'https://www.dol.gov/ofccp/pdf/pay-transp_', 'https://qbrc.swmed.edu/', 'http://www.opm.gov/policy-data-oversight/classification-qualifications/general-schedule-qualification-standards/1500/computer-science-series-1550/', 'https://apol-recruit.ucsd.edu/apply/JPF02186', 'https://www.trinityra.org/joblist.htm', 'https://www.ibm.com/watson/', 'https://drw.com/privacy-notice.', 'https://youtu.be/c5TgbpE9UBI', 'https://www.facebook.com/Mindteckglobal/', 'https://wd5.myworkday.com/usc/d/inst/1$9925/9925$45297.htmld', 'http://www.med.upenn.edu/', 'https://cherokee-federal.com/', 'https://www.linkedin.com/in/prasadmamidela', 'http://www.xome.com', 'http://whed.net/home.php.', 'https://blog.activision.com', 'https://ivs.swri.org.', 'https://e-verify.uscis.gov/esp/media/resourcesContents/WebBPPOSTERRtoWEnglishversi ...
